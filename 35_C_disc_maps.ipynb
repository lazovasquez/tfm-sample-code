# %% [markdown]
# # Input codes
# > Import notebooks

# %%
# Basic notebooks
# %run ./codes/00_libraries.ipynb
# %run ./codes/01_constants_codes.ipynb
# %run ./codes/02_constants_test_cases.ipynb

# Test cases and equations
# %run ./05_C_testcases.ipynb
# %run ./codes/06_testcases_conditions.ipynb
# %run ./codes/07_equations_functions.ipynb
# %run ./codes/08_equations_matrices.ipynb

# Stability and well-posedness
# %run ./codes/10_stability_functions.ipynb
# %run ./codes/12_stability_maps_well_posedness.ipynb

# Finite elements
# %run ./codes/21_transient_solvers.ipynb
# Out:
#  >>> β = 0.0 deg
#  >>> β = 0.25 deg
#  >>> β = -5.0 deg
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17651/2815102296.py:41: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/diff_maps/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17651/2815102296.py:41: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/diff_maps/fig1.pdf',
# /var/folders/x5/75b3n55x0sl84ztqgsdcz6qm0000gn/T/ipykernel_17651/2815102296.py:41: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('figures/diff_maps/fig1.pdf',
#  >>> β =  0.0 deg
#  >>> β =  0.25 deg
#  >>> β =  -5.0 deg
# /Users/davidvasquez/opt/anaconda3/envs/fenicsproject/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# # Discrete flow pattern maps
#
# > Differential + discrete + validation flow pattern maps.

# %%
# %run ./codes/14_stability_maps_fourier_discrete.ipynb
